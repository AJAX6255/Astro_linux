# %% [markdown]
# ### Dependencies

# %%
import sqlite3 # Database library.
import os # Folder management library.
import pickle # Serializing module.
import numpy as np # Scientific computing library.
import matplotlib.pyplot as plt # Plotting library.
from mpl_toolkits.mplot3d import Axes3D # 3D plotting tool.
from sklearn.neighbors import LocalOutlierFactor # Outlier Dection library.
from heapq import nsmallest # For finding closest period inlier to outlier

# %% [markdown]
# ### Retreive Examples from Database

# %%
# Initializing database and cursor.
star_data_db = sqlite3.connect('star_data.db')
star_data_cursor = star_data_db.cursor()

# Retrieving star_data from database.
classes = ['cep_1o', 'cep_f', 'dsct','eb_ec', 'eb_ed', 'eb_esd', 'lpv_mira_agb_c', 'lpv_mira_agb_o', 'lpv_osarg_agb',
           'lpv_osarg_rgb', 'lpv_srv_agb_c', 'lpv_srv_agb_o', 'rrab', 'rrc', 'rrd', 'rre', 't2cep']

X, Y = [], []
for label, classv in enumerate(classes):
    temp_X, temp_Y = [], []
    star_data_cursor.execute('SELECT star_features FROM '+classv)
    for row in star_data_cursor.fetchall()[:600]:
        # Deserializing features.
        features = pickle.loads(row[0])
        temp_X.append(features)
        temp_Y.append([label])
    X.append(np.array(temp_X))
    Y.append(np.array(temp_Y))
    
names = []
for classv in classes:
    temp_names = []
    star_data_cursor.execute('SELECT star_name FROM '+classv)
    for row in star_data_cursor.fetchall()[:600]:
        temp_names.append(row[0])
    names.append(temp_names)
        

# Close cursor and database    
star_data_cursor.close
star_data_db.close()

print('done')
# Out:
# done

# %% [markdown]
# ### Unsupervised Outlier Detection using Local Outlier Factor (LOF)
# The LOF score of an observation is equal to the ratio of the average local density of its k-nearest neighbors, and its own local density: a normal instance is expected to have a local density similar to that of its neighbors, while abnormal data are expected to have much smaller local density. LOF can detect both local and global outliers.
# <img src="img/lof.png", width=400, height=auto>
#
#
# ### 10 Best Outlier Candidates

# %%
# Constructing data.
names_t2cep = names[16]
X_t2cep = X[16]

best_outliers = []

# Recursively applying lof algorithm to obtain 10 best outliers.
for n in range(0,10):
    
    # Fitting the Local Outlier Detection model to the sample data set, and looking for 1 outlier. 
    lof = LocalOutlierFactor(n_neighbors=20, contamination=1/len(X_t2cep))
    outlier_pred = lof.fit_predict(X_t2cep)

    # Find the indices if all outliers.
    outlier_ind = np.where(outlier_pred == -1)[0]
    
    # Find the names of the outliers, and their coordinates.
    for ind in outlier_ind:
        best_outliers.append(names_t2cep[ind])
    
    # Remove outlier from data set.
    X_t2cep = np.delete(X_t2cep, outlier_ind[0], 0)
    names_t2cep = np.delete(names_t2cep, outlier_ind[0], 0)
    
print('The 10 best outliers are: ', best_outliers)
# Out:
# The 10 best outliers are:  ['OGLE-LMC-T2CEP-113.dat', 'OGLE-BLG-T2CEP-177.dat', 'OGLE-LMC-T2CEP-115.dat', 'OGLE-BLG-T2CEP-351.dat', 'OGLE-BLG-T2CEP-345.dat', 'OGLE-BLG-T2CEP-354.dat', 'OGLE-LMC-T2CEP-200.dat', 'OGLE-BLG-T2CEP-350.dat', 'OGLE-BLG-T2CEP-352.dat', 'OGLE-LMC-T2CEP-061.dat']

# %% [markdown]
# ### Similar Period Inliers to Outliers

# %%
feature_names = ['Amplitude', 'AndersonDarling', 'Autocor_length', 'Beyond1Std', 'CAR_mean', 'CAR_sigma', 'CAR_tau', 
                 'Con', 'Eta_e', 'FluxPercentileRatioMid20', 'FluxPercentileRatioMid35', 'FluxPercentileRatioMid50',
                 'FluxPercentileRatioMid65','FluxPercentileRatioMid80', 'Freq1_harmonics_amplitude_0',
                 'Freq1_harmonics_amplitude_1', 'Freq1_harmonics_amplitude_2', 'Freq1_harmonics_amplitude_3',
                 'Freq1_harmonics_rel_phase_0', 'Freq1_harmonics_rel_phase_1', 'Freq1_harmonics_rel_phase_2',
                 'Freq1_harmonics_rel_phase_3', 'Freq2_harmonics_amplitude_0', 'Freq2_harmonics_amplitude_1', 
                 'Freq2_harmonics_amplitude_2', 'Freq2_harmonics_amplitude_3', 'Freq2_harmonics_rel_phase_0',
                 'Freq2_harmonics_rel_phase_1', 'Freq2_harmonics_rel_phase_2', 'Freq2_harmonics_rel_phase_3',
                 'Freq3_harmonics_amplitude_0', 'Freq3_harmonics_amplitude_1', 'Freq3_harmonics_amplitude_2', 
                 'Freq3_harmonics_amplitude_3', 'Freq3_harmonics_rel_phase_0', 'Freq3_harmonics_rel_phase_1',
                 'Freq3_harmonics_rel_phase_2', 'Freq3_harmonics_rel_phase_3', 'Gskew', 'LinearTrend', 'MaxSlope',
                 'Mean', 'Meanvariance', 'MedianAbsDev', 'MedianBRP', 'PairSlopeTrend', 'PercentAmplitude', 
                 'PercentDifferenceFluxPercentile', 'Period_fit', 'PeriodLS', 'Psi_CS', 'Psi_eta', 'Q31', 'Rcs',
                 'Skew', 'SlottedA_length', 'SmallKurtosis', 'Std', 'StetsonK', 'StetsonK_AC', 'StructureFunction_index_21',
                 'StructureFunction_index_31', 'StructureFunction_index_32', 'Colour']

t2cep_periods = X[16][:,feature_names.index('Period_fit')].tolist()
similar_inliers = []

for n in range(0,10):
    
    ind_outlier = names[16].index(best_outliers[n])
    outlier_period = t2cep_periods[ind_outlier]

    # Find 10 inliers that have a similar period to outlier.
    inlier_periods = nsmallest(11, t2cep_periods, key=lambda x: abs(x-outlier_period))
    
    temp_names = []
    for inlier,period in enumerate(inlier_periods):
        ind_inlier = t2cep_periods.index(inlier_periods[inlier])
        inlier_name = names[16][ind_inlier]
        temp_names.append((inlier_name, period))
    
    similar_inliers.append(temp_names)
    
print(max(t2cep_periods))    
from pprint import pprint    
pprint(similar_inliers)
# Out:
# 2836.0077299999994
# [[('OGLE-LMC-T2CEP-113.dat', 3.0853123206644857),
#   ('OGLE-LMC-T2CEP-073.dat', 3.088140338248049),
#   ('OGLE-BLG-T2CEP-052.dat', 3.0884557844690974),
#   ('OGLE-BLG-T2CEP-316.dat', 3.126295818584072),
#   ('OGLE-BLG-T2CEP-141.dat', 3.164786926994907),
#   ('OGLE-BLG-T2CEP-099.dat', 2.9913462424347226),
#   ('OGLE-BLG-T2CEP-152.dat', 3.1972930245854765),
#   ('OGLE-SMC-T2CEP-09.dat', 2.9712227025171627),
#   ('OGLE-BLG-T2CEP-115.dat', 3.200648819680078),
#   ('OGLE-BLG-T2CEP-070.dat', 2.9358741708542717),
#   ('OGLE-LMC-T2CEP-049.dat', 3.23516969893993)],
#  [('OGLE-BLG-T2CEP-177.dat', 2836.0077299999994),
#   ('OGLE-BLG-T2CEP-345.dat', 1132.0631959999998),
#   ('OGLE-BLG-T2CEP-354.dat', 969.626286),
#   ('OGLE-LMC-T2CEP-200.dat', 842.58056625),
#   ('OGLE-BLG-T2CEP-350.dat', 724.2620452173913),
#   ('OGLE-BLG-T2CEP-352.dat', 539.2578881632654),
#   ('OGLE-LMC-T2CEP-045.dat', 127.16486839285714),
#   ('OGLE-LMC-T2CEP-147.dat', 93.12213764705884),
#   ('OGLE-BLG-T2CEP-340.dat', 85.65917557894737),
#   ('OGLE-BLG-T2CEP-179.dat', 84.65694716417909),
#   ('OGLE-SMC-T2CEP-23.dat', 78.30853228915662)],
#  [('OGLE-LMC-T2CEP-115.dat', 24.987192631578942),
#   ('OGLE-LMC-T2CEP-104.dat', 24.889024994923854),
#   ('OGLE-BLG-T2CEP-338.dat', 25.09155354330709),
#   ('OGLE-BLG-T2CEP-343.dat', 24.854126666666666),
#   ('OGLE-BLG-T2CEP-092.dat', 24.60086057142857),
#   ('OGLE-BLG-T2CEP-302.dat', 25.459485537459287),
#   ('OGLE-BLG-T2CEP-079.dat', 25.50823167664671),
#   ('OGLE-BLG-T2CEP-088.dat', 25.730475045317224),
#   ('OGLE-BLG-T2CEP-205.dat', 24.154598662873394),
#   ('OGLE-BLG-T2CEP-262.dat', 23.762778054054056),
#   ('OGLE-BLG-T2CEP-163.dat', 26.21283824074074)],
#  [('OGLE-BLG-T2CEP-351.dat', 44.14282796296295),
#   ('OGLE-BLG-T2CEP-336.dat', 44.38941952380953),
#   ('OGLE-LMC-T2CEP-032.dat', 44.50845337500001),
#   ('OGLE-LMC-T2CEP-149.dat', 42.530407522388046),
#   ('OGLE-BLG-T2CEP-344.dat', 42.241164029850744),
#   ('OGLE-LMC-T2CEP-174.dat', 46.78361602649007),
#   ('OGLE-LMC-T2CEP-055.dat', 41.04467550432277),
#   ('OGLE-SMC-T2CEP-19.dat', 40.96307248157248),
#   ('OGLE-LMC-T2CEP-080.dat', 40.907904440734555),
#   ('OGLE-LMC-T2CEP-051.dat', 40.58290085106383),
#   ('OGLE-BLG-T2CEP-288.dat', 40.3085241025641)],
#  [('OGLE-BLG-T2CEP-345.dat', 1132.0631959999998),
#   ('OGLE-BLG-T2CEP-354.dat', 969.626286),
#   ('OGLE-LMC-T2CEP-200.dat', 842.58056625),
#   ('OGLE-BLG-T2CEP-350.dat', 724.2620452173913),
#   ('OGLE-BLG-T2CEP-352.dat', 539.2578881632654),
#   ('OGLE-LMC-T2CEP-045.dat', 127.16486839285714),
#   ('OGLE-LMC-T2CEP-147.dat', 93.12213764705884),
#   ('OGLE-BLG-T2CEP-340.dat', 85.65917557894737),
#   ('OGLE-BLG-T2CEP-179.dat', 84.65694716417909),
#   ('OGLE-SMC-T2CEP-23.dat', 78.30853228915662),
#   ('OGLE-LMC-T2CEP-025.dat', 67.82158485714285)],
#  [('OGLE-BLG-T2CEP-354.dat', 969.626286),
#   ('OGLE-LMC-T2CEP-200.dat', 842.58056625),
#   ('OGLE-BLG-T2CEP-345.dat', 1132.0631959999998),
#   ('OGLE-BLG-T2CEP-350.dat', 724.2620452173913),
#   ('OGLE-BLG-T2CEP-352.dat', 539.2578881632654),
#   ('OGLE-LMC-T2CEP-045.dat', 127.16486839285714),
#   ('OGLE-LMC-T2CEP-147.dat', 93.12213764705884),
#   ('OGLE-BLG-T2CEP-340.dat', 85.65917557894737),
#   ('OGLE-BLG-T2CEP-179.dat', 84.65694716417909),
#   ('OGLE-SMC-T2CEP-23.dat', 78.30853228915662),
#   ('OGLE-LMC-T2CEP-025.dat', 67.82158485714285)],
#  [('OGLE-LMC-T2CEP-200.dat', 842.58056625),
#   ('OGLE-BLG-T2CEP-350.dat', 724.2620452173913),
#   ('OGLE-BLG-T2CEP-354.dat', 969.626286),
#   ('OGLE-BLG-T2CEP-345.dat', 1132.0631959999998),
#   ('OGLE-BLG-T2CEP-352.dat', 539.2578881632654),
#   ('OGLE-LMC-T2CEP-045.dat', 127.16486839285714),
#   ('OGLE-LMC-T2CEP-147.dat', 93.12213764705884),
#   ('OGLE-BLG-T2CEP-340.dat', 85.65917557894737),
#   ('OGLE-BLG-T2CEP-179.dat', 84.65694716417909),
#   ('OGLE-SMC-T2CEP-23.dat', 78.30853228915662),
#   ('OGLE-LMC-T2CEP-025.dat', 67.82158485714285)],
#  [('OGLE-BLG-T2CEP-350.dat', 724.2620452173913),
#   ('OGLE-LMC-T2CEP-200.dat', 842.58056625),
#   ('OGLE-BLG-T2CEP-352.dat', 539.2578881632654),
#   ('OGLE-BLG-T2CEP-354.dat', 969.626286),
#   ('OGLE-BLG-T2CEP-345.dat', 1132.0631959999998),
#   ('OGLE-LMC-T2CEP-045.dat', 127.16486839285714),
#   ('OGLE-LMC-T2CEP-147.dat', 93.12213764705884),
#   ('OGLE-BLG-T2CEP-340.dat', 85.65917557894737),
#   ('OGLE-BLG-T2CEP-179.dat', 84.65694716417909),
#   ('OGLE-SMC-T2CEP-23.dat', 78.30853228915662),
#   ('OGLE-LMC-T2CEP-025.dat', 67.82158485714285)],
#  [('OGLE-BLG-T2CEP-352.dat', 539.2578881632654),
#   ('OGLE-BLG-T2CEP-350.dat', 724.2620452173913),
#   ('OGLE-LMC-T2CEP-200.dat', 842.58056625),
#   ('OGLE-LMC-T2CEP-045.dat', 127.16486839285714),
#   ('OGLE-BLG-T2CEP-354.dat', 969.626286),
#   ('OGLE-LMC-T2CEP-147.dat', 93.12213764705884),
#   ('OGLE-BLG-T2CEP-340.dat', 85.65917557894737),
#   ('OGLE-BLG-T2CEP-179.dat', 84.65694716417909),
#   ('OGLE-SMC-T2CEP-23.dat', 78.30853228915662),
#   ('OGLE-LMC-T2CEP-025.dat', 67.82158485714285),
#   ('OGLE-BLG-T2CEP-172.dat', 66.20814314214465)],
#  [('OGLE-LMC-T2CEP-061.dat', 1.1814933661217997),
#   ('OGLE-BLG-T2CEP-209.dat', 1.1812794532173914),
#   ('OGLE-BLG-T2CEP-008.dat', 1.182922760372566),
#   ('OGLE-LMC-T2CEP-153.dat', 1.175163677004289),
#   ('OGLE-BLG-T2CEP-030.dat', 1.1713864517057724),
#   ('OGLE-LMC-T2CEP-089.dat', 1.1672998514427197),
#   ('OGLE-BLG-T2CEP-228.dat', 1.2044229700533298),
#   ('OGLE-LMC-T2CEP-107.dat', 1.2091578229346485),
#   ('OGLE-BLG-T2CEP-051.dat', 1.2094683746043566),
#   ('OGLE-LMC-T2CEP-071.dat', 1.1521897333897588),
#   ('OGLE-BLG-T2CEP-004.dat', 1.2119027388949086)]]

# %% [markdown]
# ### Comparing Outlier Feature to Mean and Std of the Data

# %%
mean_features = np.mean(X[16], axis=0)
std_features = np.std(X[16], axis=0)

upper_bound = np.absolute(mean_features + std_features)
lower_bound = np.absolute(mean_features - std_features)

for n in range(0,10):
    print(best_outliers[n])
    
    ind_outlier = names[16].index(best_outliers[n])
    outlier_features = np.absolute(X[16][ind_outlier])
    
    outlier_upper = np.greater(outlier_features, upper_bound)
    outlier_lower = np.less(outlier_features, lower_bound)
    
    ind_upper = np.where(outlier_upper == True)[0]
    ind_lower = np.where(outlier_lower == True)[0]
    
    print('These features of the outlier are bigger than mean+std')
    for ind in ind_upper:
        ratio = outlier_features[ind]/upper_bound[ind]
        if ratio>2:
            print(feature_names[ind], ratio)
        
    print(' ')
    
    print('These features of the outlier are smaller than mean-std')
    for ind in ind_lower:
        ratio = outlier_features[ind]/lower_bound[ind]
        if ratio<0.1:
            print(feature_names[ind], ratio)
            
    print(' ')
# Out:
# OGLE-LMC-T2CEP-113.dat
# These features of the outlier are bigger than mean+std
# Eta_e 15.5658855723
# MaxSlope 6.42506511358
# Psi_eta 2.79413244958
#
# These features of the outlier are smaller than mean-std
# CAR_tau 0.00939386637319
# Freq1_harmonics_amplitude_3 0.0345021801956
# Freq1_harmonics_rel_phase_3 0.0317674862013
# Freq2_harmonics_rel_phase_1 0.0678646868643
# Gskew 0.0990501597169
# LinearTrend 0.000224568175184
# Period_fit 0.026496890858
# PeriodLS 4.31168929213e-47
# SlottedA_length 0.000714746680317
#
# OGLE-BLG-T2CEP-177.dat
# These features of the outlier are bigger than mean+std
# Amplitude 3.27341722477
# Autocor_length 10.6866224696
# CAR_tau 4.12212238256
# Freq1_harmonics_amplitude_0 3.53885456468
# Freq1_harmonics_amplitude_2 2.41324656932
# Freq2_harmonics_amplitude_0 3.30740434832
# Freq2_harmonics_amplitude_3 3.91021391342
# Freq3_harmonics_amplitude_0 3.12821523478
# Gskew 6.15996986017
# LinearTrend 12.3051501857
# Meanvariance 3.43231733058
# PercentAmplitude 4.56809005412
# PercentDifferenceFluxPercentile 3.53774626909
# Period_fit 17.1380759357
# Q31 2.61054077937
# Rcs 3.7125941266
# SlottedA_length 18.26089823
# SmallKurtosis 3.6137259825
# Std 3.1807041372
# Colour 3.07978448267
#
# These features of the outlier are smaller than mean-std
# CAR_mean 0.0030383519906
# Eta_e 4.16652733408e-05
# Freq2_harmonics_rel_phase_3 0.0512110299372
# PeriodLS 2.67243014689e-121
#
# OGLE-LMC-T2CEP-115.dat
# These features of the outlier are bigger than mean+std
# CAR_mean 5.18724302319
# CAR_sigma 7.88894277141
# Eta_e 12.3226344517
# MaxSlope 4.40176728283
# SmallKurtosis 7.20209827752
#
# These features of the outlier are smaller than mean-std
# CAR_tau 0.00104631001423
# Con 0.0
# Freq1_harmonics_rel_phase_3 0.0519765897649
# Freq3_harmonics_rel_phase_1 0.0795412199769
# LinearTrend 0.0370430297712
# PeriodLS 1.89007802825e-71
# SlottedA_length 0.0578258093615
#
# OGLE-BLG-T2CEP-351.dat
# These features of the outlier are bigger than mean+std
# Eta_e 8.45263880225
# Freq2_harmonics_amplitude_2 3.23200558618
# Freq2_harmonics_amplitude_3 3.19670604591
# Freq3_harmonics_amplitude_1 4.34928363805
# MedianBRP 2.09223086992
# Rcs 2.21013766241
# Skew 2.52051506901
# SmallKurtosis 6.95193653368
# Colour 3.94592984611
#
# These features of the outlier are smaller than mean-std
# CAR_mean 0.0217676123779
# PeriodLS 9.36513319964e-13
# SlottedA_length 0.000197606435149
#
# OGLE-BLG-T2CEP-345.dat
# These features of the outlier are bigger than mean+std
# Amplitude 4.28645258962
# Autocor_length 10.7883998265
# CAR_tau 16.3650636516
# Freq1_harmonics_amplitude_0 3.89486804589
# Freq1_harmonics_amplitude_1 4.24573290126
# Freq1_harmonics_amplitude_2 7.00152205395
# Freq1_harmonics_amplitude_3 13.0214793717
# Freq2_harmonics_amplitude_0 8.03989510197
# Freq2_harmonics_amplitude_2 7.76096310386
# Freq2_harmonics_amplitude_3 5.70866017547
# Freq3_harmonics_amplitude_0 9.99633740249
# Freq3_harmonics_amplitude_1 2.81899385656
# Freq3_harmonics_amplitude_2 7.59714432617
# Freq3_harmonics_amplitude_3 4.77291992335
# LinearTrend 4.7726258578
# Meanvariance 3.64796164671
# MedianAbsDev 4.31288707725
# PercentAmplitude 3.35333477588
# PercentDifferenceFluxPercentile 3.79923971517
# Period_fit 6.84109031574
# Q31 3.68171770106
# Rcs 2.34849526092
# SmallKurtosis 7.27240066364
# Std 3.95694515915
# Colour 4.41802113649
#
# These features of the outlier are smaller than mean-std
# CAR_mean 0.000895808532527
# Eta_e 0.000431829868434
# Freq3_harmonics_rel_phase_1 0.0436554221704
# PeriodLS 9.04418300504e-240
# SlottedA_length 0.0248101185944
#
# OGLE-BLG-T2CEP-354.dat
# These features of the outlier are bigger than mean+std
# Amplitude 3.0455109546
# Autocor_length 2.95154334875
# CAR_tau 3.85431456688
# Freq1_harmonics_amplitude_0 2.82387058971
# Freq1_harmonics_amplitude_1 4.99151204173
# Freq1_harmonics_amplitude_2 3.54264650331
# Freq1_harmonics_amplitude_3 5.48956008597
# Freq2_harmonics_amplitude_0 4.40720960258
# Freq2_harmonics_amplitude_1 9.55673625995
# Freq2_harmonics_amplitude_2 2.84148358183
# Freq2_harmonics_amplitude_3 3.38091681229
# Freq2_harmonics_rel_phase_1 2.00236640031
# Freq3_harmonics_amplitude_0 3.14747314979
# Freq3_harmonics_amplitude_1 2.41982546465
# LinearTrend 4.71507930541
# Meanvariance 2.95822636241
# MedianAbsDev 2.77257026394
# PercentAmplitude 2.62904866065
# PercentDifferenceFluxPercentile 3.19167061309
# Period_fit 5.85947941641
# Q31 2.54338083706
# Rcs 2.52577364705
# SlottedA_length 5.4089928913
# SmallKurtosis 6.33454330225
# Std 2.79154097166
# Colour 4.38641653017
#
# These features of the outlier are smaller than mean-std
# CAR_mean 0.0033089375676
# Eta_e 0.000995846369436
# Freq2_harmonics_rel_phase_2 0.0549189218613
# PeriodLS 3.46510160576e-73
#
# OGLE-LMC-T2CEP-200.dat
# These features of the outlier are bigger than mean+std
# Amplitude 2.8186721611
# Autocor_length 3.25687541931
# CAR_tau 8.18849157124
# Freq1_harmonics_amplitude_0 2.85437613715
# Freq1_harmonics_amplitude_1 2.53746849704
# Freq2_harmonics_amplitude_0 2.94605180991
# Freq2_harmonics_amplitude_2 3.64910720113
# Freq2_harmonics_amplitude_3 5.72512894215
# Freq3_harmonics_amplitude_0 2.93279745679
# Freq3_harmonics_amplitude_2 4.0153963953
# Freq3_harmonics_amplitude_3 4.07465757167
# Gskew 5.08576127964
# LinearTrend 2.13243253636
# Meanvariance 2.75887158118
# PercentAmplitude 3.03985711159
# PercentDifferenceFluxPercentile 2.72632499218
# Period_fit 5.09173849337
# Q31 3.10965027874
# Rcs 2.55082572896
# SlottedA_length 7.07502609024
# SmallKurtosis 7.9708225289
# Std 2.9525159145
#
# These features of the outlier are smaller than mean-std
# CAR_mean 0.00176636309077
# Eta_e 2.06781660348e-05
# Freq1_harmonics_rel_phase_3 0.00801837877524
# PeriodLS 4.44379126869e-149
#
# OGLE-BLG-T2CEP-350.dat
# These features of the outlier are bigger than mean+std
# Autocor_length 6.81908290918
# CAR_tau 4.4284062958
# Freq1_harmonics_amplitude_2 4.91965922474
# Freq2_harmonics_amplitude_0 3.05320625368
# Freq2_harmonics_amplitude_1 3.177995496
# Freq2_harmonics_amplitude_3 3.53549547921
# Freq3_harmonics_amplitude_0 3.73562592135
# Freq3_harmonics_amplitude_1 2.87657403011
# LinearTrend 2.24615559747
# Period_fit 4.37673628212
# Rcs 2.17768430326
# SmallKurtosis 7.19949505918
# Colour 2.77867068487
#
# These features of the outlier are smaller than mean-std
# CAR_mean 0.00299681337912
# Eta_e 6.76190255504e-05
# PeriodLS 1.04171320243e-159
#
# OGLE-BLG-T2CEP-352.dat
# These features of the outlier are bigger than mean+std
# Amplitude 2.10186157364
# Autocor_length 2.74798863504
# CAR_tau 3.12295331066
# Con 2.77535859385
# Freq3_harmonics_amplitude_1 2.0871080069
# Freq3_harmonics_amplitude_2 2.01864892142
# Freq3_harmonics_amplitude_3 2.18505872077
# Gskew 2.57633959561
# Meanvariance 2.2766591796
# PercentAmplitude 2.44967680058
# PercentDifferenceFluxPercentile 2.45013701302
# Period_fit 3.25875086252
# SmallKurtosis 4.87195148319
# Colour 2.6120796734
#
# These features of the outlier are smaller than mean-std
# CAR_mean 0.00367220034937
# Eta_e 0.00616495262345
# Freq3_harmonics_rel_phase_2 0.0432872599246
# PeriodLS 2.01920677466e-146
# SlottedA_length 0.00368725199245
#
# OGLE-LMC-T2CEP-061.dat
# These features of the outlier are bigger than mean+std
# Eta_e 2.15750340224
# SmallKurtosis 10.0496012193
#
# These features of the outlier are smaller than mean-std
# CAR_tau 0.0119316344989
# Con 0.0
# Freq2_harmonics_rel_phase_1 0.0617132614534
# Gskew 0.0380962152757
# LinearTrend 0.0959754491379
# Period_fit 0.010146752587
# PeriodLS 2.29965178427e-157
# Skew 0.00994267249378
# SlottedA_length 0.0014294933608
