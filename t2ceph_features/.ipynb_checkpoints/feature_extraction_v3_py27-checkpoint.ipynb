# %% [markdown]
# ### Dependencies

# %%
import numpy as np # Scientific computing 
import pandas as pd # Dataframe to organize content
import os # Creating folders
import pickle # Serializing module
import FATS # Feature extraction library
import sqlite3 # Database library
# Out:
# /home/amanjot_bhullar/anaconda3/envs/py27/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### Scrape T2CEPH Files from Astrouw -- Extract Features then Store in Database

# %%
# Read list file from web
list_file_url = 'ftp://ftp.astrouw.edu.pl/ogle/ogle3/OIII-CVS/lmc/t2cep/t2cep.dat'
list_file = pd.read_csv(list_file_url, sep="\s+", header=None)

# This is a list of all type-2 cepheids on the astrouw website
t2ceph_astrouw = list_file[0].tolist()
# Remove lightcurve 170 as it does not have V-band data
t2ceph_astrouw.remove('OGLE-LMC-T2CEP-170')

# Initializing database and cursor
star_data_db = sqlite3.connect('star_data.db')
star_data_cursor = star_data_db.cursor()
# Initializing table:'astrouw_data' and columns:ex.'star_data' with datatype:ex.'BLOB'
star_data_cursor.execute("CREATE TABLE IF NOT EXISTS astrouw_data(star_data BLOB, star_features BLOB, star_label REAL)")
    
# This loop will obtain the necessary data for each star
for star in t2ceph_astrouw:
    print(star)
    # Reading Data for I-band
    star_data_url_I = 'ftp://ftp.astrouw.edu.pl/ogle/ogle3/OIII-CVS/lmc/t2cep/phot/I/'+star+'.dat'
    star_data_I = pd.read_csv(star_data_url_I, sep="\s+", names=["time", "magnitude", "error"])
    
    # Reading Data for V-band
    star_data_url_V = 'ftp://ftp.astrouw.edu.pl/ogle/ogle3/OIII-CVS/lmc/t2cep/phot/V/'+star+'.dat'
    star_data_V = pd.read_csv(star_data_url_V, sep="\s+", names=["time2", "magnitude2", "error2"])

    # Creating lists from pandas dataframe (these are the parameters used to compute the features)
    magnitude = star_data_I.magnitude.tolist()
    time = star_data_I.time.tolist()
    error = star_data_I.error.tolist()
    magnitude2 = star_data_V.magnitude2.tolist()
    
    #Extracting Features
    parameters = np.array([magnitude, time, error])
    feature_space = FATS.FeatureSpace(Data=['magnitude','time', 'error'])
    features = feature_space.calculateFeature(parameters)
    features_array = features.result(method='array')
    # Custom feature:colour -- is also added to array
    colour = np.mean(magnitude) - np.mean(magnitude2)
    features_array.append(colour)

    
    # Serializing star_data so that it can be stored in database
    star_pickled = pickle.dumps((star, time, magnitude, error, magnitude2), pickle.HIGHEST_PROTOCOL)
    # Serializing features so that it can be stored in database
    features_pickled = pickle.dumps(features_array, pickle.HIGHEST_PROTOCOL)
    
    # Storing star_data in database for future reference
    star_data_cursor.execute("INSERT INTO astrouw_data (star_data, star_features, star_label) VALUES (?,?,?)",
                             (sqlite3.Binary(star_pickled), sqlite3.Binary(features_pickled), 1))
    star_data_db.commit()

print("Data stored.")
# Out:
# OGLE-LMC-T2CEP-001
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# /home/amanjot_bhullar/anaconda3/envs/py27/lib/python2.7/site-packages/scipy/optimize/_minimize.py:394: RuntimeWarning: Method nelder-mead cannot handle constraints nor bounds.
#   RuntimeWarning)
# OGLE-LMC-T2CEP-002
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-003
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-004
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-005
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-006
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-007
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-008
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-009
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-010
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-011
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-012
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-013
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-014
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-015
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-016
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-017
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-018
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-019
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-020
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-021
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-022
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-023
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-024
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-025
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-026
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-027
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-028
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-029
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-030
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-031
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-032
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-033
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-034
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-035
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-036
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-037
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-038
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-039
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-040
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-041
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-042
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-043
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-044
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-045
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-046
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-047
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-048
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-049
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-050
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-051
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-052
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-053
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-054
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-055
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-056
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-057
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-058
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-059
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-060
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-061
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-062
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-063
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-064
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-065
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-066
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-067
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-068
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-069
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-070
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-071
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-072
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-073
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-074
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-075
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-076
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-077
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-078
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-079
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# ...
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-178
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-179
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-180
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-181
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-182
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-183
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-184
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-185
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-186
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-187
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-188
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-189
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-190
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-191
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-192
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-193
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-194
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-195
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-196
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-197
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-198
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-199
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-200
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-201
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-202
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# OGLE-LMC-T2CEP-203
# Warning: the feature Color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Eta_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature Q31_color could not be calculated because ['magnitude', 'time', 'magnitude2'] are needed.
# Warning: the feature StetsonJ could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Warning: the feature StetsonL could not be calculated because ['magnitude', 'time', 'error', 'magnitude2', 'error2'] are needed.
# Data stored.

# %% [markdown]
# ### Retrieve Data from Database

# %%
# Initializing database and cursor
star_data_db = sqlite3.connect('star_data.db')
star_data_cursor = star_data_db.cursor()

# Retrieving star_data from database
star_data_cursor.execute('SELECT star_features FROM astrouw_data')
for row in star_data_cursor.fetchall()[:10]:
    # BLOB field needs to be strinyfied with str() before loading with pickle
    data = pickle.loads(str(row[0]))
    print(data)
    print(len(data))
    
# star_data_cursor.execute('SELECT star_data FROM astrouw_data')
# for row in star_data_cursor.fetchall()[:2]:
#     # BLOB field needs to be strinyfied with str() before loading with pickle
#     data = pickle.loads(str(row[0]))
#     print(data)
#     print(len(data))

# Close cursor and database    
star_data_cursor.close
star_data_db.close()
# Out:
# [0.18499999999999872, 1.0, 1.0, 0.42627345844504022, 14.061372533110655, -0.15019728491165785, 1.2620557405150516, 0.0, 9.1681910611143049, 0.35530085959885377, 0.55300859598854801, 0.65902578796562361, 0.77650429799427911, 0.89398280802293462, 0.15897611649657187, 0.0070678308709647541, 0.016380768072360458, 0.02200955839443073, 0.0, 2.7742712078476748, 2.3300297762197375, 1.6898228829388791, 0.018328853848264329, 0.0021637144534108819, 0.0056558841809685751, 0.006283598188073009, 0.0, 1.9206237630028975, 2.1098725168754857, 0.59633792849177536, 0.014400011511165576, 0.0031919370653122831, 0.0013415421665693608, 0.0052872097996190933, 0.0, -0.50626214793621604, 1.9060788942680489, 1.8452216904347409, 0.0079999999999955662, 5.7251413633939328e-06, 0.29821884137312638, 17.746235924932975, 0.006853891651048021, 0.11599999999999966, 0.12064343163538874, -0.10000000000000001, 0.013014084507042147, 0.019661971830985725, 1.8140546566632754, 5.3114109601311169e-67, 0.23846927745224347, 0.13469800388042619, 0.22800000000000153, 0.055039340235115641, 0.0040158603546224126, 3.9092000000000553, -1.4497166480898442, 0.12163077824342657, 0.90441238660192436, 0.74461527187940191, 1.6481336576639232, 2.1987168315945311, 1.4358690516637389, -0.69958760447878987]
